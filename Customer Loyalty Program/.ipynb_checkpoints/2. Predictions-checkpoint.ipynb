# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import my_scripts.WiSe as WiSe
import matplotlib.pyplot as plt
import my_scripts.data_cleaning as dc
import my_scripts.TabNet_trainer as tn
import my_scripts.XGBoost_trainer as xg
import my_scripts.RidgeRegression_trainer as rr

# %% [markdown]
# # 2. Predictions

# %% [markdown]
# # A. Ridge Regression

# %%
df = pd.read_csv('customer_data.csv')
df = df.drop(columns=['Customer', 'Effective To Date'])
target = 'Response'
df[target] = df[target].apply(lambda x: 0 if x == 'No' else 1)

# %%
rr.RidgeRegression_classifer_trainer?

# %%
# trainer definition
RidgeRegression_full = rr.RidgeRegression_classifer_trainer(df, target, std=False, power_trans=True)

# hyper-params. definiton
learning_rates = [0.001, 0.01, 0.1, 0.5]
degrees = [1, 2, 3, 5]
n_components=[5, 6, 10, 12, 15, 17, 20]

# model training 
RidgeRegression_full.train_model_on_best_params(learning_rates=learning_rates, degrees=degrees, 
                                                n_components=n_components, end_evaluation=True)
# Out:
# Accuracy: 0.86
# MCC Score: 0.27
# F1 Score: 0.17

# %% [markdown]
# **Observations:** problem with class distribution (the 'No' class is over represented compated to the 'Yes' class). The Ridge Regression Trainer doesn't include yet weight distribution or particular loss encoding to battle weight distribution problem.

# %% [markdown]
# # B. TabNet

# %%
TabNet_full = tn.TabNet_binary_classifer_trainer(df, target, n_d=10, n_a=10, lr=0.1, lambda_sparse=1e-5)
TabNet_full.train_model(max_epochs=100, end_evaluation=True, verbose=1)
# Out:
# Device used : cpu
# epoch 0  | loss: 0.61197 | train_auc: 0.54396 | valid_auc: 0.51212 |  0:00:02s
# epoch 1  | loss: 0.43971 | train_auc: 0.50909 | valid_auc: 0.48737 |  0:00:04s
# epoch 2  | loss: 0.41281 | train_auc: 0.5829  | valid_auc: 0.53436 |  0:00:06s
# epoch 3  | loss: 0.41556 | train_auc: 0.62156 | valid_auc: 0.593   |  0:00:09s
# epoch 4  | loss: 0.40355 | train_auc: 0.57536 | valid_auc: 0.53382 |  0:00:11s
# epoch 5  | loss: 0.40201 | train_auc: 0.6111  | valid_auc: 0.61556 |  0:00:13s
# epoch 6  | loss: 0.39598 | train_auc: 0.61948 | valid_auc: 0.61224 |  0:00:16s
# epoch 7  | loss: 0.39436 | train_auc: 0.60838 | valid_auc: 0.60996 |  0:00:19s
# epoch 8  | loss: 0.41299 | train_auc: 0.59529 | valid_auc: 0.60282 |  0:00:21s
# epoch 9  | loss: 0.39011 | train_auc: 0.61987 | valid_auc: 0.60568 |  0:00:23s
# epoch 10 | loss: 0.38783 | train_auc: 0.6188  | valid_auc: 0.61898 |  0:00:25s
# epoch 11 | loss: 0.38681 | train_auc: 0.62992 | valid_auc: 0.64367 |  0:00:28s
# epoch 12 | loss: 0.38231 | train_auc: 0.61296 | valid_auc: 0.62581 |  0:00:31s
# epoch 13 | loss: 0.37287 | train_auc: 0.67277 | valid_auc: 0.6721  |  0:00:33s
# epoch 14 | loss: 0.3741  | train_auc: 0.70125 | valid_auc: 0.71845 |  0:00:36s
# epoch 15 | loss: 0.37026 | train_auc: 0.72388 | valid_auc: 0.71222 |  0:00:38s
# epoch 16 | loss: 0.36854 | train_auc: 0.73168 | valid_auc: 0.71922 |  0:00:40s
# epoch 17 | loss: 0.3699  | train_auc: 0.74176 | valid_auc: 0.73071 |  0:00:43s
# epoch 18 | loss: 0.3631  | train_auc: 0.74778 | valid_auc: 0.72708 |  0:00:45s
# epoch 19 | loss: 0.35769 | train_auc: 0.7533  | valid_auc: 0.74667 |  0:00:48s
# epoch 20 | loss: 0.34726 | train_auc: 0.7562  | valid_auc: 0.75873 |  0:00:50s
# epoch 21 | loss: 0.33896 | train_auc: 0.77383 | valid_auc: 0.78343 |  0:00:52s
# epoch 22 | loss: 0.34495 | train_auc: 0.76653 | valid_auc: 0.7593  |  0:00:54s
# epoch 23 | loss: 0.34639 | train_auc: 0.77543 | valid_auc: 0.76929 |  0:00:57s
# epoch 24 | loss: 0.34292 | train_auc: 0.78105 | valid_auc: 0.77307 |  0:00:59s
# epoch 25 | loss: 0.34015 | train_auc: 0.78479 | valid_auc: 0.77202 |  0:01:01s
# epoch 26 | loss: 0.33476 | train_auc: 0.78651 | valid_auc: 0.78307 |  0:01:04s
# epoch 27 | loss: 0.33647 | train_auc: 0.78952 | valid_auc: 0.78617 |  0:01:06s
# epoch 28 | loss: 0.33064 | train_auc: 0.78644 | valid_auc: 0.77463 |  0:01:08s
# epoch 29 | loss: 0.33441 | train_auc: 0.78979 | valid_auc: 0.77572 |  0:01:10s
# epoch 30 | loss: 0.33954 | train_auc: 0.78339 | valid_auc: 0.76373 |  0:01:13s
# epoch 31 | loss: 0.339   | train_auc: 0.78838 | valid_auc: 0.77622 |  0:01:16s
# epoch 32 | loss: 0.33787 | train_auc: 0.79042 | valid_auc: 0.78024 |  0:01:18s
# epoch 33 | loss: 0.33905 | train_auc: 0.7882  | valid_auc: 0.78362 |  0:01:21s
# epoch 34 | loss: 0.33766 | train_auc: 0.79682 | valid_auc: 0.79434 |  0:01:23s
# epoch 35 | loss: 0.3339  | train_auc: 0.79458 | valid_auc: 0.78615 |  0:01:25s
# epoch 36 | loss: 0.33151 | train_auc: 0.79203 | valid_auc: 0.7811  |  0:01:27s
# epoch 37 | loss: 0.33575 | train_auc: 0.79826 | valid_auc: 0.80319 |  0:01:30s
# epoch 38 | loss: 0.33852 | train_auc: 0.78127 | valid_auc: 0.78355 |  0:01:32s
# epoch 39 | loss: 0.34417 | train_auc: 0.77242 | valid_auc: 0.76427 |  0:01:34s
# epoch 40 | loss: 0.33988 | train_auc: 0.77992 | valid_auc: 0.78547 |  0:01:37s
# epoch 41 | loss: 0.34441 | train_auc: 0.76399 | valid_auc: 0.75327 |  0:01:39s
# epoch 42 | loss: 0.35661 | train_auc: 0.75111 | valid_auc: 0.76956 |  0:01:42s
# epoch 43 | loss: 0.35515 | train_auc: 0.76223 | valid_auc: 0.7678  |  0:01:44s
# epoch 44 | loss: 0.348   | train_auc: 0.77014 | valid_auc: 0.77667 |  0:01:46s
# epoch 45 | loss: 0.3469  | train_auc: 0.7783  | valid_auc: 0.7875  |  0:01:49s
# epoch 46 | loss: 0.34351 | train_auc: 0.75887 | valid_auc: 0.76532 |  0:01:52s
# epoch 47 | loss: 0.35014 | train_auc: 0.76289 | valid_auc: 0.75393 |  0:01:54s
# epoch 48 | loss: 0.35147 | train_auc: 0.72879 | valid_auc: 0.73115 |  0:01:57s
# epoch 49 | loss: 0.34758 | train_auc: 0.72029 | valid_auc: 0.72413 |  0:01:59s
# epoch 50 | loss: 0.34454 | train_auc: 0.77284 | valid_auc: 0.77106 |  0:02:01s
# epoch 51 | loss: 0.34311 | train_auc: 0.76743 | valid_auc: 0.77941 |  0:02:04s
# epoch 52 | loss: 0.33966 | train_auc: 0.76733 | valid_auc: 0.77879 |  0:02:06s
# epoch 53 | loss: 0.34492 | train_auc: 0.77057 | valid_auc: 0.77564 |  0:02:09s
# epoch 54 | loss: 0.34801 | train_auc: 0.77015 | valid_auc: 0.78242 |  0:02:11s
# epoch 55 | loss: 0.35109 | train_auc: 0.77096 | valid_auc: 0.77845 |  0:02:13s
# epoch 56 | loss: 0.34968 | train_auc: 0.76685 | valid_auc: 0.77512 |  0:02:16s
# epoch 57 | loss: 0.35145 | train_auc: 0.7683  | valid_auc: 0.78309 |  0:02:18s
# epoch 58 | loss: 0.34301 | train_auc: 0.77103 | valid_auc: 0.78248 |  0:02:20s
# epoch 59 | loss: 0.34444 | train_auc: 0.77235 | valid_auc: 0.78003 |  0:02:22s
# epoch 60 | loss: 0.34179 | train_auc: 0.7724  | valid_auc: 0.7835  |  0:02:25s
# epoch 61 | loss: 0.34488 | train_auc: 0.76409 | valid_auc: 0.77803 |  0:02:27s
# epoch 62 | loss: 0.34178 | train_auc: 0.77399 | valid_auc: 0.78676 |  0:02:29s
# epoch 63 | loss: 0.33941 | train_auc: 0.77441 | valid_auc: 0.78205 |  0:02:33s
# epoch 64 | loss: 0.34069 | train_auc: 0.77555 | valid_auc: 0.7854  |  0:02:35s
# epoch 65 | loss: 0.33904 | train_auc: 0.77247 | valid_auc: 0.78103 |  0:02:37s
# epoch 66 | loss: 0.34063 | train_auc: 0.77094 | valid_auc: 0.77996 |  0:02:41s
# epoch 67 | loss: 0.33841 | train_auc: 0.77856 | valid_auc: 0.77959 |  0:02:43s
# epoch 68 | loss: 0.34116 | train_auc: 0.77984 | valid_auc: 0.77532 |  0:02:45s
# epoch 69 | loss: 0.34221 | train_auc: 0.77959 | valid_auc: 0.78161 |  0:02:48s
# epoch 70 | loss: 0.3428  | train_auc: 0.78001 | valid_auc: 0.7809  |  0:02:50s
# epoch 71 | loss: 0.34391 | train_auc: 0.77944 | valid_auc: 0.78501 |  0:02:52s
# epoch 72 | loss: 0.34186 | train_auc: 0.78443 | valid_auc: 0.78144 |  0:02:54s
# epoch 73 | loss: 0.34183 | train_auc: 0.77013 | valid_auc: 0.77492 |  0:02:57s
# epoch 74 | loss: 0.34006 | train_auc: 0.78131 | valid_auc: 0.7848  |  0:02:59s
# epoch 75 | loss: 0.33976 | train_auc: 0.78679 | valid_auc: 0.79353 |  0:03:01s
# epoch 76 | loss: 0.337   | train_auc: 0.7897  | valid_auc: 0.79334 |  0:03:03s
# epoch 77 | loss: 0.33648 | train_auc: 0.79062 | valid_auc: 0.79465 |  0:03:05s
# epoch 78 | loss: 0.33801 | train_auc: 0.78866 | valid_auc: 0.79925 |  0:03:08s
# epoch 79 | loss: 0.34172 | train_auc: 0.78082 | valid_auc: 0.79707 |  0:03:11s
# epoch 80 | loss: 0.34171 | train_auc: 0.78132 | valid_auc: 0.80077 |  0:03:13s
# epoch 81 | loss: 0.34111 | train_auc: 0.78348 | valid_auc: 0.79997 |  0:03:15s
# epoch 82 | loss: 0.34093 | train_auc: 0.78547 | valid_auc: 0.80262 |  0:03:17s
# epoch 83 | loss: 0.33988 | train_auc: 0.78151 | valid_auc: 0.80158 |  0:03:21s
# epoch 84 | loss: 0.34159 | train_auc: 0.78564 | valid_auc: 0.80151 |  0:03:23s
# epoch 85 | loss: 0.3393  | train_auc: 0.78719 | valid_auc: 0.80357 |  0:03:25s
# epoch 86 | loss: 0.33798 | train_auc: 0.78405 | valid_auc: 0.80592 |  0:03:28s
# epoch 87 | loss: 0.3402  | train_auc: 0.78577 | valid_auc: 0.8002  |  0:03:30s
# epoch 88 | loss: 0.33978 | train_auc: 0.78802 | valid_auc: 0.80177 |  0:03:32s
# epoch 89 | loss: 0.3392  | train_auc: 0.78843 | valid_auc: 0.80281 |  0:03:35s
# epoch 90 | loss: 0.33983 | train_auc: 0.78773 | valid_auc: 0.80226 |  0:03:37s
# epoch 91 | loss: 0.33666 | train_auc: 0.79291 | valid_auc: 0.80659 |  0:03:39s
# epoch 92 | loss: 0.33341 | train_auc: 0.79463 | valid_auc: 0.80089 |  0:03:41s
# epoch 93 | loss: 0.33475 | train_auc: 0.79764 | valid_auc: 0.80842 |  0:03:44s
# epoch 94 | loss: 0.33295 | train_auc: 0.79739 | valid_auc: 0.80617 |  0:03:47s
# epoch 95 | loss: 0.33504 | train_auc: 0.79432 | valid_auc: 0.80712 |  0:03:49s
# epoch 96 | loss: 0.33782 | train_auc: 0.78077 | valid_auc: 0.7983  |  0:03:51s
# epoch 97 | loss: 0.3399  | train_auc: 0.78556 | valid_auc: 0.79101 |  0:03:53s
# epoch 98 | loss: 0.34062 | train_auc: 0.77785 | valid_auc: 0.79024 |  0:03:55s
# epoch 99 | loss: 0.34019 | train_auc: 0.78801 | valid_auc: 0.78892 |  0:03:58s
# Stop training because you reached max_epochs = 100 with best_epoch = 93 and best_valid_auc = 0.80842
# Best weights from best epoch are automatically used!
# Accuracy: 0.87
# MCC Score: 0.28
# F1 Score: 0.24

# %% [markdown]
# **Observations:** a simple TabNet on the entire dataset slightly outperforms Ridge Regression. Still, problem with class distribution. We will try to augment ROC curve at the expense of accuracy.

# %%
TabNet_balance = tn.TabNet_binary_classifer_trainer(df, target, n_d=10, n_a=10, lr=0.1, lambda_sparse=1e-5)
TabNet_balance.train_model(max_epochs=100, end_evaluation=True, verbose=0, weights=1)
# Out:
# Stop training because you reached max_epochs = 100 with best_epoch = 83 and best_valid_auc = 0.80497
# Best weights from best epoch are automatically used!
# Accuracy: 0.70
# MCC Score: 0.27
# F1 Score: 0.38

# %%
TabNet_balance.get_model().classes_
# Out:
# array([0, 1], dtype=int64)

# %%
weights={1:0.85, 0:0.15}
